# %% [markdown]
# ## Name :-Thanvitha sivani Godasu
#
# ## Domain:- Data Science
#
# ## Prodigy Infotech intern
#
# ## Task  :- Titanic Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')
import statsmodels.api as sm
import scipy.stats as stats

# %%
df = pd.read_excel(r"C:\Users\ROHAN SUVARNA\OneDrive\Documents\Rohan Suvarna\Projects\Data science\titanic3.xls")
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
## top data

df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
## bottom

df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
# column
df.columns                  # calculating column in list
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
# It will tell you what has the exact value in the column
df.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
## information in dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
## finding null value

df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
## delete the null values

df.dropna().sum()
# Out:
# pclass       0.0
# survived     0.0
# name         0.0
# sex          0.0
# age          0.0
# sibsp        0.0
# parch        0.0
# ticket       0.0
# fare         0.0
# cabin        0.0
# embarked     0.0
# boat         0.0
# body         0.0
# home.dest    0.0
# dtype: float64

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.dropna(subset=['age'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1046 entries, 0 to 1308
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1046 non-null   int64
#  1   survived   1046 non-null   int64
#  2   name       1046 non-null   object
#  3   sex        1046 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1046 non-null   int64
#  6   parch      1046 non-null   int64
#  7   ticket     1046 non-null   object
#  8   fare       1045 non-null   float64
#  9   embarked   1044 non-null   object
#  10  boat       417 non-null    object
#  11  body       120 non-null    float64
#  12  home.dest  685 non-null    object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 114.4+ KB

# %%
del df["cabin"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   embarked   1307 non-null   object
#  10  boat       486 non-null    object
#  11  body       121 non-null    float64
#  12  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 133.1+ KB

# %% [markdown]
# # Explorartory data analysis

# %% [markdown]
# ## Plot the Histograms

# %%
df.hist(figsize = (20,30))
# Out:
# array([[<AxesSubplot:title={'center':'pclass'}>,
#         <AxesSubplot:title={'center':'survived'}>,
#         <AxesSubplot:title={'center':'age'}>],
#        [<AxesSubplot:title={'center':'sibsp'}>,
#         <AxesSubplot:title={'center':'parch'}>,
#         <AxesSubplot:title={'center':'fare'}>],
#        [<AxesSubplot:title={'center':'body'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
Skewness  = pd.DataFrame({'Skewness':[stats.skew(df.pclass),stats.skew(df.survived),stats.skew(df.sibsp),stats.skew(df.parch)]},index=['pclass','survived','sibsp','parch'])
Skewness  # measure the skewness of the required columns
# Out:
#           Skewness
# pclass   -0.597961
# survived  0.485847
# sibsp     3.839814
# parch     3.664872

# %% [markdown]
# ##### When value is not symmetric is called Skewness
# - pclass are not skewed
# - survived is balanced
# - parch is less skewed then sibsp

# %% [markdown]
# #### highest age in this ship

# %%
top_ages = df['age'].value_counts().head(5)

# Create a bar plot using Seaborn
sns.barplot(x=top_ages.index, y=top_ages.values)
plt.title('Top 5 Most Common Ages')
plt.xlabel('Age')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# - Above graphs shows that top 5 age which is present in titanic ship between 18-30, in which 24 age highest in the ship.

# %% [markdown]
# ### Sex ratio in the ship

# %%
top_sex = df['sex'].value_counts()

# Create a bar plot using Seaborn
sns.barplot(x=top_sex.index, y=top_sex.values)
plt.title(' Sex ratio')
plt.xlabel('Sex')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# - Highest sex ratio present in the ship is male

# %% [markdown]
# ### who survived most Gender wise

# %%
# Calculate survival rates by gender
survival_by_gender = df.groupby('sex')['survived'].mean().reset_index()

# Create a bar plot to visualize survival rates by gender
plt.figure(figsize=(10, 4))
sns.barplot(x='sex', y='survived', data=survival_by_gender)
plt.title('Survival Rates by Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.ylim(0, 1)  # Set y-axis limit to be between 0 and 1 (for percentages)
plt.show()

# %% [markdown]
# #### above graph we said that female ratio is high as compared to man who survived

# %% [markdown]
# ### which age is survived most

# %%
# Calculate survival rates by gender
survival_by_gender = df.groupby('age')['survived'].mean().reset_index().head()

# Create a bar plot to visualize survival rates by gender
plt.figure(figsize=(15, 10))
sns.barplot(x='age', y='survived', data=survival_by_age)
plt.title('Survival Rates by age')
plt.xlabel('age')
plt.ylabel('Survival Rate')

plt.show()

# %% [markdown]
# ### age distribution using graph

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='age', bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Bivirate  Distribution

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# - In this code, we first create a pairplot using sns.pairplot(), which shows scatterplots and histograms for each pair of numerical variables.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='pclass', y='fare')
plt.title('Fare Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# #### passenger 1 having highest fare

# %% [markdown]
# ### correlation

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='pclass', y='age', hue='survived', split=True)
plt.title('Age Distribution by Passenger Class and Survival')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## Conclusion

# %%
1) pclass are not skewed
- survived is balanced
- parch is less skewed then sibsp

2) Above graphs shows that top 5 age which is present in titanic ship between 18-30, in which 24 age highest in the ship.

3) above graph we said that female ratio is high as compared to man who survived

4) passenger 1 having highest fare
